# %%
import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread("../samples/mountain_lake.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# ## Step 1: Color Quantization

# %%
from color_quantization import kmeans
bin_image = kmeans(image, 18)
plt.imshow(bin_image)
# Out:
# (541, 800, 3)
